# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -- personal lib --
import request_chart as chart
import request_order as req
import R_ts_functions as r
import ts_analysis as ts
# Out:
# [NbConvertApp] Converting notebook request_chart.ipynb to script
# [NbConvertApp] Writing 1429 bytes to request_chart.py
# [NbConvertApp] Converting notebook upbit_keys.ipynb to script
# [NbConvertApp] Writing 247 bytes to upbit_keys.py
# [NbConvertApp] Converting notebook request_order.ipynb to script
# [NbConvertApp] Writing 9629 bytes to request_order.py

# %%
ts.show_plot_trade()

# %%
# def get_balance():
#     return float(req.asset_check()[0]['balance'])

# %%
Y = ts.get_ts(40)

# %%
b > a
# Out:
# True

# %%
b_ < a_
# Out:
# False

# %%
a_
# Out:
# 30604400.0

# %%
b_
# Out:
# 30606750.0

# %%
ma_5-ma_20
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20    -5350.0
# 21    -6100.0
# 22   -10250.0
# 23   -12100.0
# 24   -11100.0
# 25    -9400.0
# 26    -7250.0
# 27    -7500.0
# 28    -8350.0
# 29    -8550.0
# 30    -6800.0
# 31    -4250.0
# 32     -200.0
# 33      650.0
# 34     3850.0
# 35     1750.0
# 36     -800.0
# 37    -2300.0
# 38    -2050.0
# 39      200.0
# Name: opening_price, dtype: float64

# %%
b_ < a_
# Out:
# False

# %%
ts.refresh_ts(Y)
ts.show_plot_trade()

ma_5 = ts.get_ma(Y, days = 5)
ma_20 = ts.get_ma(Y, days = 20)

a_ = ma_5[len(ma_5)-1] # a'
a = ma_5[len(ma_5)-2] # a
b_ = ma_20[len(ma_20)-1] # b'
b = ma_20[len(ma_20)-2] # b

# 매초 갱신

# 주문 조건 로직
# 매수
if (len(req.asset_check()) == 1): # 보유 코인이 없다면
    print('ready...')
    if b > a and b_ < a_ : # ma_1이 ma_2를 넘으면
        print('buy!')
        # req.ord_bid_price(req.get_balance() * 0.99) 매수주문
    else:
        print('wait...')
else:
    print('empty balance...')
    
# 매도
# if (len(req.asset_check()) != 1): # 코인 잔고가 있다면
    # if( chart.get_curret_price() < req.get_buy_price() * 0.998): # 매수 가격보다 내려간다면
        # req.ord_ask_market() 매도주문
    # elif(): 현재가가 이평선 아래로 어느정도 내려오면
        # req.ord_ask_market() 매도
        # 매도금액 저장
# Out:
# ready...
# wait...

# %%
ask = req.get_last_ask()
ask['state']

# %%
req.get_buy_price()
# Out:
# COIN_BALANCE_EMPTY

# %%
req.get_balance()
# Out:
# 18557.7115101
